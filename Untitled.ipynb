# %%
import pandas as pd

df = pd.read_csv("s3://ipre-poc/outputs/recommendations/recommendations.csv")

print(df.groupby("customer_id").size().describe())
# Out:
# count    1000.0
# mean        5.0
# std         0.0
# min         5.0
# 25%         5.0
# 50%         5.0
# 75%         5.0
# max         5.0
# dtype: float64

# %%
import pandas as pd

df = pd.read_csv("s3://ipre-poc/outputs/recommendations/recommendations.csv")

print("Customers covered:", df.customer_id.nunique())
print("Coverage %:", df.customer_id.nunique() / 1000)
print("Avg support:", df.support.mean())
print("Avg confidence:", df.confidence.mean())
print(df.head())
# Out:
# Customers covered: 1000
# Coverage %: 1.0
# Avg support: 0.43556002184174497
# Avg confidence: 0.43556002184174497
#   customer_id recommended_product  cluster_id          segment  \
# 0          C1                 P22           0  East_Industrial
# 1          C1                 P22           0  East_Industrial
# 2          C1                 P22           0  East_Industrial
# 3          C1                 P22           0  East_Industrial
# 4          C1                 P28           0  East_Industrial
#
#   trigger_product   support  confidence     score  recommended_qty  \
# 0             P11  0.733333    0.733333  0.587625                7
# 1             P12  0.600000    0.600000  0.480958                7
# 2             P30  0.533333    0.533333  0.427625                7
# 3             P17  0.400000    0.400000  0.320958                7
# 4             P11  0.200000    0.200000  0.160958                7
#
#                                       reason  rank
# ...

# %%
import pandas as pd

df = pd.read_csv("s3://ipre-poc/outputs/recommendations/recommendations.csv")

print(df.groupby("customer_id").size().describe())
# Out:
# count    1220.000000
# mean        4.985246
# std         0.150837
# min         2.000000
# 25%         5.000000
# 50%         5.000000
# 75%         5.000000
# max         5.000000
# dtype: float64

# %%
import pandas as pd

df = pd.read_csv("s3://ipre-poc/outputs/recommendations/recommendations.csv")

print("Customers covered:", df.customer_id.nunique())
print("Coverage %:", df.customer_id.nunique() / 1000)
print("Avg support:", df.support.mean())
print("Avg confidence:", df.confidence.mean())
print(df.head())
# Out:
# Customers covered: 1220
# Coverage %: 1.22
# Avg support: 0.23811332422337414
# Avg confidence: 0.23811332422337414
#   customer_id recommended_product  cluster_id             segment  \
# 0      C00001              P05055           1  Northeast_Flooring
# 1      C00001              P04848           1  Northeast_Flooring
# 2      C00001              P00094           1  Northeast_Flooring
# 3      C00001              P00319           1  Northeast_Flooring
# 4      C00001              P00333           1  Northeast_Flooring
#
#   trigger_product  support  confidence     score  recommended_qty  \
# 0          P04848     0.50        0.50  0.400319               16
# 1          P05055     0.50        0.50  0.400319               16
# 2          P00029     0.25        0.25  0.200319               16
# 3          P00029     0.25        0.25  0.200319               16
# 4          P00029     0.25        0.25  0.200319               16
#
# ...

# %%
import pandas as pd

df = pd.read_csv("s3://ipre-poc/outputs/recommendations/recommendations.csv")

print(df)
# Out:
#      customer_id recommended_product  cluster_id               segment  \
# 0         C00001              P05055           1    Northeast_Flooring
# 1         C00001              P04848           1    Northeast_Flooring
# 2         C00001              P00094           1    Northeast_Flooring
# 3         C00001              P00319           1    Northeast_Flooring
# 4         C00001              P00333           1    Northeast_Flooring
# ...          ...                 ...         ...                   ...
# 6077      C01244              P03624           0  Northwest_Electrical
# 6078      C01244              P00019           0  Northwest_Electrical
# 6079      C01244              P00020           0  Northwest_Electrical
# 6080      C01244              P00096           0  Northwest_Electrical
# 6081      C01244              P00160           0  Northwest_Electrical
#
#      trigger_product   support  confidence     score  recommended_qty  \
# ...
